# %%
# !pip install datadotworld 
# !pip install datadotworld[pandas]

# %%
# !dw configure

# %%
from google.colab import drive
import pandas as pd 
import numpy as np
import datadotworld as dw

# %%
# drive.mount("/content/drive")

# %%
cd "drive/My Drive/Colab Notebooks/matrix"
# Out:
# [Errno 2] No such file or directory: 'drive/My Drive/Colab Notebooks/matrix'
# /content/drive/My Drive/Colab Notebooks/matrix

# %%
# !mkdir data
# Out:
# mkdir: cannot create directory ‘data’: File exists

# %%
# !echo 'data' > .gitignore

# %%
! git add .gitignore

# %%
dw.load_dataset('datafiniti/mens-shoe-prices')
# Out:
# LocalDataset('/root/.dw/cache/datafiniti/mens-shoe-prices/latest/datapackage.json')

# %%
df = data.dataframes['7004_1']
df.shape
# Out:
# (19387, 48)

# %%
df.sample(5)
# Out:
#                          id                  asins  ... websiteids   weight
# 11069  AVpfw4n2LJeJML43DSur                    NaN  ...        NaN  3.0 lbs
# 9573   AVpfVeksilAPnD_xZ4MQ                    NaN  ...        NaN      NaN
# 12100  AVpe5w44LJeJML43x59u  B006L6RZKK,B00061TRU2  ...        NaN      NaN
# 12877  AVpfuM141cnluZ0-qE9h                    NaN  ...        NaN      NaN
# 6934   AVpfO1QZLJeJML435LGn                    NaN  ...        NaN      NaN
#
# [5 rows x 48 columns]

# %%
df.columns
# Out:
# Index(['id', 'asins', 'brand', 'categories', 'colors', 'count', 'dateadded',
#        'dateupdated', 'descriptions', 'dimension', 'ean', 'features',
#        'flavors', 'imageurls', 'isbn', 'keys', 'manufacturer',
#        'manufacturernumber', 'merchants', 'name', 'prices_amountmin',
#        'prices_amountmax', 'prices_availability', 'prices_color',
#        'prices_condition', 'prices_count', 'prices_currency',
#        'prices_dateadded', 'prices_dateseen', 'prices_flavor', 'prices_issale',
#        'prices_merchant', 'prices_offer', 'prices_returnpolicy',
#        'prices_shipping', 'prices_size', 'prices_source', 'prices_sourceurls',
#        'prices_warranty', 'quantities', 'reviews', 'sizes', 'skus',
#        'sourceurls', 'upc', 'vin', 'websiteids', 'weight'],
#       dtype='object')

# %%
df.prices_currency.value_counts()
# Out:
# USD                                                   18524
# AUD                                                     338
# CAD                                                     303
# EUR                                                     107
# GBP                                                      22
# PalmBeach Jewelry - Walmart.com                           3
# UnbeatableSale.com, Inc. - Walmart.com                    3
# new                                                       3
# New with box                                              3
# Wholesale Costume and Party Supplies - Walmart.com        2
# New without tags                                          1
# Shoes.com                                                 1
# SHOEBACCA LTD. - Walmart.com                              1
# Name: prices_currency, dtype: int64

# %%
df_usd = df[df.prices_currency == 'USD'].copy() 
df_usd.shape
# Out:
# (18524, 48)

# %%
df_usd.prices_amountmin.head()
# Out:
# 0    39.89
# 1    51.99
# 2    40.02
# 3    50.31
# 4    46.26
# Name: prices_amountmin, dtype: object

# %%
df_usd['prices_amountmin'] = df_usd.prices_amountmin.astype(np.float)
df_usd['prices_amountmin'].hist()

# %%
filter_max = np.percentile(df_usd['prices_amountmin'], 99)
filter_max
# Out:
# 895.0

# %%
df_usd_filter = df_usd[ df_usd ['prices_amountmin'] < filter_max]

# %%
df_usd_filter.prices_amountmin.hist(bins=100)

# %%
# !git add matrix_one/day3.ipynb

# %%
# !git commit -m "changes to Read Men's Shoe Prices dataset from data.world"
# Out:
# [master dc80908] changes to Read Men's Shoe Prices dataset from data.world
#  2 files changed, 2 insertions(+), 129 deletions(-)
#  rewrite .gitignore (100%)
#  create mode 100644 matrix_one/day3.ipynb

# %%
# !git config --global user.email "anna.truszewskaa@gmail.com"
# !git config --global user.name "anntru"

# %%
# !git push -u origin master
# Out:
# To https://github.com/anntru/matrix.git
#  ! [rejected]        master -> master (non-fast-forward)
# error: failed to push some refs to 'https://7f8eda0f1ef71ccded2ac01d0215047c5c095127@github.com/anntru/matrix.git'
# hint: Updates were rejected because the tip of your current branch is behind
# hint: its remote counterpart. Integrate the remote changes (e.g.
# hint: 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git revert HEAD
# Out:
# error: Your local changes to the following files would be overwritten by merge:
# 	matrix_one/day3.ipynb
# Please commit your changes or stash them before you merge.
# Aborting
# fatal: revert failed

# %%
# !git pull
# Out:
# error: Your local changes to the following files would be overwritten by merge:
# 	matrix_one/day3.ipynb
# Please commit your changes or stash them before you merge.
# Aborting

# %%
# !git commit
# Out:
# On branch master
# Your branch and 'origin/master' have diverged,
# and have 1 and 1 different commits each, respectively.
#   (use "git pull" to merge the remote branch into yours)
#
# Changes not staged for commit:
# 	modified:   matrix_one/day3.ipynb
#
# no changes added to commit
